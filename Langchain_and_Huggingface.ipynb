# %% [markdown]
# <a href="https://colab.research.google.com/github/Mukul98/Langchain/blob/main/Langchain_and_Huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.13
#     Uninstalling langchain-core-0.3.13:
#       Successfully uninstalled langchain-core-0.3.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id, max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("What is Generative AI")
# Out:
# 'M?\n\nMLM stands for Multi-Level Marketing, also known as Network Marketing. It’s a business model in which a company distributes products or services through a network of independent contractors who earn money through recruiting and selling. The company profits from the sales of their products or services, as well as from the sales of their recruits’ sales.\n\nIn an MLM, participants often earn money through a combination of retail sales, commissions from recruiting new members, and bonuses for the sales and recruiting efforts of their downline (the network of recruits beneath them). The compensation plan of an MLM may vary widely depending on the company, but in general, the more you sell and the more people you recruit, the more money you can potentially earn.\n\nMLM companies can offer a wide range of products and services, from health and wellness products, to cosmetics, to financial services, and more. Some MLMs have a reputation for being pyramid schemes, where the majority o
# ...

# %%
from langchain import PromptTemplate, LLMChain

question = "What is Generative AI?"

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

print(prompt)
# llm_chain = LLMChain(prompt=prompt, llm=llm)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\n\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(prompt=prompt,llm=llm)
print(llm_chain.invoke(question))
# Out:
# {'question': 'What is Generative AI?', 'text': "\n\n1. Artificial Intelligence (AI): AI is a branch of computer science that aims to create systems capable of performing tasks that would normally require human intelligence. This includes learning, reasoning, problem-solving, and perception.\n\n2. Machine Learning (ML): A subset of AI, machine learning is a method of data analysis that automates the building of analytical models. It's based on the idea that systems can learn from data, identify patterns, and make decisions with minimal human intervention.\n\n3. Deep Learning: A subset of machine learning, deep learning is a neural network with multiple layers that can learn to recognize patterns in data. It's"}

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM

# %%
model_id = "gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke("Tesla is a company")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'Tesla is a company that made a lot of money for themselves to make this the top carmaker in the world to date. With just one year left in 2014, Google seems to be on their way to becoming a dominant player and in that time, they have become a huge success. It all started with a video for their new video game, Call of Duty 4: Modern Warfare 3.\n\nAfter doing quite a bit during CES 2013, YouTube asked Valve on December 6th, 2014 if they could make Call of'
